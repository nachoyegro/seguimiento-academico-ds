# %% [markdown]
# ## Estadísticas básicas sobre materias

# %%
import pandas as pd
from source.transformer import DataTransformer
from source.manipulator import DataManipulator
import json
with open('alumnos_test.json', 'r') as archivo_alumnos:
    data=archivo_alumnos.read()
df = DataTransformer().transform_to_dataframe(json.loads(data))
manipulator = DataManipulator()
df
# Out:
#       alumno carrera       fecha materia nota resultado
# 0      10380       W  2019-02-07   90000    8         P
# 1      10380       W  2019-02-07   80005    7         P
# 2      10380       W  2019-02-07   90028    7         P
# 3      10380       W  2019-02-07   80003    9         P
# 4      10380       W  2019-07-23   01032    6         P
# 5      10380       W  2019-02-07   80000    8         P
# 6      10380       W  2019-02-07   00752   10         P
# 7      10409       W  2014-02-26   90000    A         P
# 8      10409       W  2014-07-23   01033              U
# 9      10467       W  2013-12-12   01304              U
# 10     10467       W  2013-07-31   90000    A         P
# 11     10467       W  2013-07-31   00487    8         P
# 12     10467       W  2013-07-31   01051    8         P
# 13     10467       W  2013-07-31   01036    7         P
# 14     10467       W  2013-07-31   01045    6         P
# 15     10467       W  2013-07-31   01040    8         P
# 16     10467       W  2013-07-31   01044    9         P
# 17     10467       W  2013-07-31   90028    A         P
# 18     10467       W  2013-07-31   00054    6         P
# 19     10467       W  2013-07-31   01049   10         P
# 20     10467       W  2013-07-31   00752    6         P
# 21     10467       W  2013-07-31   01043    A         A
# 22     10467       W  2013-07-31   01042    A         A
# 23     10467       W  2013-07-31   01041    A         A
# 24     10467       W  2013-07-31   01039    A         A
# 25     10467       W  2013-07-31   01047    A         A
# 26     10467       W  2013-07-31   01038    A         A
# 27     10467       W  2013-07-31   01037    A         A
# 28     10467       W  2013-07-31   01035    A         A
# 29     10467       W  2013-07-31   01034    A         A
# ...      ...     ...         ...     ...  ...       ...
# 13050  53473       W  2019-07-16   80000    A         A
# 13051  53473       W  2019-07-16   80003    A         A
# 13052  53590       W  2019-07-16   80000    A         A
# 13053  53590       W  2019-07-16   80003    A         A
# 13054  53638       W  2019-07-16   80000    A         A
# 13055  54002       W  2019-07-16   80000    A         A
# 13056  54084       W  2019-07-16   80000    A         A
# 13057  54452       W  2019-07-16   80000    A         A
# 13058   6498       W  2015-07-22   00487    7         P
# 13059   6498       W  2017-12-15   00752    8         P
# 13060   6498       W  2015-07-21   01032    8         P
# 13061   6498       W  2015-12-22   01033              U
# 13062   6498       W  2016-07-14   01033    9         P
# 13063   6498       W  2017-07-19   01037              U
# 13064   6498       W  2016-12-14   01034    8         P
# 13065   6498       W  2016-07-20   90028    A         P
# 13066   6498       W  2015-12-22   01035    9         P
# 13067   6498       W  2017-12-20   01037              U
# 13068   6498       W  2016-12-22   01041    9         P
# 13069   6498       W  2015-12-16   90000   10         P
# 13070   6693       W  2016-07-20   00487              U
# 13071   6693       W  2016-07-21   01032              U
# 13072   6693       W  2016-02-27   80005    A         A
# 13073   6693       W  2016-02-27   80003    A         A
# 13074   6693       W  2016-02-27   80000    A         A
# 13075   7854       W  2019-02-11   80000    A         A
# 13076   8796       W  2015-07-22   00487              U
# 13077   8796       W  2015-12-21   01032              U
# 13078   8796       W  2015-12-16   00487              U
# 13079   8796       W  2015-02-23   90000    A         P
#
# [13080 rows x 6 columns]

# %% [markdown]
# ### Cantidad de alumnos que cursaron una materia en un período

# %%
df = manipulator.filtrar_alumnos_de_materia(df, '628')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'materia.codigo'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-ac7960957ee7> in <module>
# ----> 1 df = manipulator.filtrar_alumnos_de_materia(df, '628')
#
# ~/Projects/seguimiento-academico-ds/source/manipulator.py in filtrar_alumnos_de_materia(self, df, materia)
#      20             :return Dataframe
#      21         """
# ---> 22         df = df.loc[df['materia.codigo'] ==
#      23                     materia]
#      24         return df
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'materia.codigo'

# %%
manipulator.filtrar_periodo(df, None, '2010-01-01')
# Out:
#       id nota alumno carrera       fecha resultado  materia.id  \
# 12    13    A      1       D  2002-08-22         A         168
# 78    79           2       D  2004-07-01         U         168
# 79    80           2       D  2005-07-01         U         168
# 80    81    9      2       D  2008-07-01         P         168
# 139  140           3       D  2002-12-15         U         168
# 140  141           3       D  2007-07-01         U         168
#
#     materia.materia  materia.plan materia.nucleo  materia.creditos  \
# 12        QUÍMICA I          2003           None                 9
# 78        QUÍMICA I          2003           None                 9
# 79        QUÍMICA I          2003           None                 9
# 80        QUÍMICA I          2003           None                 9
# 139       QUÍMICA I          2003           None                 9
# 140       QUÍMICA I          2003           None                 9
#
#     materia.area materia.codigo
# 12          None            628
# 78          None            628
# 79          None            628
# 80          None            628
# 139         None            628
# 140         None            628

# %% [markdown]
# ### Alumnos aprobados

# %%
manipulator.aprobados_de_materia(df, '628')
# Out:
#       id nota alumno carrera       fecha resultado  materia.id  \
# 12    13    A      1       D  2002-08-22         A         168
# 80    81    9      2       D  2008-07-01         P         168
# 141  142    8      3       D  2010-07-08         P         168
#
#     materia.materia  materia.plan materia.nucleo  materia.creditos  \
# 12        QUÍMICA I          2003           None                 9
# 80        QUÍMICA I          2003           None                 9
# 141       QUÍMICA I          2003           None                 9
#
#     materia.area materia.codigo
# 12          None            628
# 80          None            628
# 141         None            628

# %% [markdown]
# ### Alumnos desaprobados

# %%
manipulator.desaprobados_de_materia(df, '628')
# Out:
# Empty DataFrame
# Columns: [id, nota, alumno, carrera, fecha, resultado, materia.id, materia.materia, materia.plan, materia.nucleo, materia.creditos, materia.area, materia.codigo]
# Index: []

# %% [markdown]
# ### Alumnos ausentes

# %%
manipulator.ausentes_de_materia(df, '628')
# Out:
# 4

# %% [markdown]
# ### Ausentes y Desaprobados

# %%
ausentes_df = manipulator.ausentes_de_materia(df, '628')
desaprobados_df = manipulator.desaprobados_de_materia(df, '628')
pd.concat([desaprobados_df, ausentes_df])
# Out:
#       id nota alumno carrera       fecha resultado  materia.id  \
# 78    79           2       D  2004-07-01         U         168
# 79    80           2       D  2005-07-01         U         168
# 139  140           3       D  2002-12-15         U         168
# 140  141           3       D  2007-07-01         U         168
#
#     materia.materia  materia.plan materia.nucleo  materia.creditos  \
# 78        QUÍMICA I          2003           None                 9
# 79        QUÍMICA I          2003           None                 9
# 139       QUÍMICA I          2003           None                 9
# 140       QUÍMICA I          2003           None                 9
#
#     materia.area materia.codigo
# 78          None            628
# 79          None            628
# 139         None            628
# 140         None            628
